# %%
import pandas as pd
import numpy as np
df = pd.read_csv('test.csv')
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# check if there are null datas in the dataset
df.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#check for negative age
any(df['Age']<0)
# Out:
# False

# %%
# check the number of unique values in each column
df.nunique()
# Out:
# PassengerId    418
# Pclass           3
# Name           418
# Sex              2
# Age             79
# SibSp            7
# Parch            8
# Ticket         363
# Fare           169
# Cabin           76
# Embarked         3
# dtype: int64

# %%
df.shape
# Out:
# (418, 11)

# %%
#Imputing missing values 

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import SimpleImputer
imp_S = SimpleImputer(strategy='most_frequent')
imp_I = IterativeImputer(max_iter=10, random_state=0,min_value=0,max_value=100)
df[['Pclass','Age','SibSp','Parch','Fare']]=imp_I.fit_transform(df[['Pclass','Age','SibSp','Parch','Fare']])
df[['Cabin','Embarked']]=imp_S.fit_transform(df[['Cabin','Embarked']])

# %%
# check if there are null datas in the dataset
df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#Classifing Age to 5 different catagories

from sklearn.preprocessing import FunctionTransformer
bins = [-1, 1, 13, 20, 60, np.inf]
labels = ['infant', 'kid', 'teen', 'adult', 'senior citizen']
age_trans = FunctionTransformer(pd.cut, kw_args={'bins': bins, 'labels': labels, 'retbins': False})
df['Age']=age_trans.fit_transform(df['Age'])

# %%
# testing catagories
df['Age'].unique()
#df.isnull().sum()
# Out:
# ['adult', 'senior citizen', 'teen', 'kid', 'infant']
# Categories (5, object): ['infant' < 'kid' < 'teen' < 'adult' < 'senior citizen']

# %%
df["Pclass"]=df["Pclass"].astype("category")
df["Sex"]=df["Sex"].astype("category")
df["Embarked"]=df["Embarked"].astype("category")
df.dtypes
# Out:
# PassengerId       int64
# Pclass         category
# Name             object
# Sex            category
# Age            category
# SibSp           float64
# Parch           float64
# Ticket           object
# Fare            float64
# Cabin            object
# Embarked       category
# dtype: object

# %%
Group_ticket=pd.DataFrame(df.groupby('Ticket')['Ticket'].count().reset_index(name='person_per_Ticket'))
Group_ticket['Ticket_type']=Group_ticket['person_per_Ticket'].apply(lambda x: 'multi_person' if x>1 else 'single_person')
Group_ticket
# Out:
#           Ticket  person_per_Ticket    Ticket_type
# 0         110469                  1  single_person
# 1         110489                  1  single_person
# 2         110813                  1  single_person
# 3         111163                  1  single_person
# 4         112051                  1  single_person
# ..           ...                ...            ...
# 358  W./C. 14260                  1  single_person
# 359  W./C. 14266                  1  single_person
# 360   W./C. 6607                  2   multi_person
# 361   W./C. 6608                  1  single_person
# 362  W.E.P. 5734                  1  single_person
#
# [363 rows x 3 columns]

# %%
df=df.merge(Group_ticket, how='left', left_on='Ticket', right_on='Ticket')

# %%
df.tail(20)
# Out:
#      PassengerId Pclass                                             Name  \
# 398         1290    3.0                   Larsson-Rondberg, Mr. Edvard A
# 399         1291    3.0                         Conlon, Mr. Thomas Henry
# 400         1292    1.0                          Bonnell, Miss. Caroline
# 401         1293    2.0                                  Gale, Mr. Harry
# 402         1294    1.0                   Gibson, Miss. Dorothy Winifred
# 403         1295    1.0                           Carrau, Mr. Jose Pedro
# 404         1296    1.0                     Frauenthal, Mr. Isaac Gerald
# 405         1297    2.0     Nourney, Mr. Alfred (Baron von Drachstedt")"
# 406         1298    2.0                        Ware, Mr. William Jeffery
# 407         1299    1.0                       Widener, Mr. George Dunton
# 408         1300    3.0                  Riordan, Miss. Johanna Hannah""
# 409         1301    3.0                        Peacock, Miss. Treasteall
# 410         1302    3.0                           Naughton, Miss. Hannah
# 411         1303    1.0  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304    3.0                   Henriksson, Miss. Jenny Lovisa
# 413         1305    3.0                               Spector, Mr. Woolf
# 414         1306    1.0                     Oliva y Ocana, Dona. Fermina
# 415         1307    3.0                     Saether, Mr. Simon Sivertsen
# 416         1308    3.0                              Ware, Mr. Frederick
# 417         1309    3.0                         Peter, Master. Michael J
#
#         Sex    Age  SibSp  Parch              Ticket      Fare  \
# 398    male  adult    0.0    0.0              347065    7.7750
# 399    male  adult    0.0    0.0               21332    7.7333
# 400  female  adult    0.0    0.0               36928  164.8667
# 401    male  adult    1.0    0.0               28664   21.0000
# 402  female  adult    0.0    1.0              112378   59.4000
# 403    male   teen    0.0    0.0              113059   47.1000
# 404    male  adult    1.0    0.0               17765   27.7208
# 405    male   teen    0.0    0.0       SC/PARIS 2166   13.8625
# 406    male  adult    1.0    0.0               28666   10.5000
# 407    male  adult    1.0    1.0              113503  211.5000
# 408  female  adult    0.0    0.0              334915    7.7208
# 409  female    kid    1.0    1.0  SOTON/O.Q. 3101315   13.7750
# 410  female  adult    0.0    0.0              365237    7.7500
# 411  female  adult    1.0    0.0               19928   90.0000
# 412  female  adult    0.0    0.0              347086    7.7750
# 413    male  adult    0.0    0.0           A.5. 3236    8.0500
# 414  female  adult    0.0    0.0            PC 17758  108.9000
# 415    male  adult    0.0    0.0  SOTON/O.Q. 3101262    7.2500
# 416    male  adult    0.0    0.0              359309    8.0500
# 417    male  adult    1.0    1.0                2668   22.3583
#
#                Cabin Embarked  person_per_Ticket    Ticket_type
# 398  B57 B59 B63 B66        S                  1  single_person
# 399  B57 B59 B63 B66        Q                  1  single_person
# 400               C7        S                  2   multi_person
# 401  B57 B59 B63 B66        S                  1  single_person
# 402  B57 B59 B63 B66        C                  2   multi_person
# 403  B57 B59 B63 B66        S                  1  single_person
# 404              D40        C                  1  single_person
# 405              D38        C                  1  single_person
# 406  B57 B59 B63 B66        S                  1  single_person
# 407              C80        C                  4   multi_person
# 408  B57 B59 B63 B66        Q                  1  single_person
# 409  B57 B59 B63 B66        S                  3   multi_person
# 410  B57 B59 B63 B66        Q                  1  single_person
# 411              C78        Q                  1  single_person
# 412  B57 B59 B63 B66        S                  1  single_person
# 413  B57 B59 B63 B66        S                  1  single_person
# 414             C105        C                  1  single_person
# 415  B57 B59 B63 B66        S                  1  single_person
# 416  B57 B59 B63 B66        S                  1  single_person
# 417  B57 B59 B63 B66        C                  1  single_person

# %%
df.to_csv('trans_test.csv',index= False)

# %%
df.dtypes
# Out:
# PassengerId             int64
# Pclass               category
# Name                   object
# Sex                  category
# Age                  category
# SibSp                 float64
# Parch                 float64
# Ticket                 object
# Fare                  float64
# Cabin                  object
# Embarked             category
# person_per_Ticket       int64
# Ticket_type            object
# dtype: object
